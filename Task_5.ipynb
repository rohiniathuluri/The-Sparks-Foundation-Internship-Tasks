# %% [markdown]
# # Data Science & Business Analytics Intern Nov Batch 2021
#
# # Author:Attuluri Rohini
#
# GRIPNOV21
#
# Task5:Perform ‘Exploratory Data Analysis’ on dataset ‘Indian Premier League’
#
# As a sports analysts, find out the most successful teams, players and factors
# contributing win or loss of a team.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv('matches.csv')

# %%
data
# Out:
#         id  season           city        date                        team1  \
# 0        1    2017      Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1        2    2017           Pune  2017-04-06               Mumbai Indians
# 2        3    2017         Rajkot  2017-04-07                Gujarat Lions
# 3        4    2017         Indore  2017-04-08       Rising Pune Supergiant
# 4        5    2017      Bangalore  2017-04-08  Royal Challengers Bangalore
# ..     ...     ...            ...         ...                          ...
# 751  11347    2019         Mumbai    05/05/19        Kolkata Knight Riders
# 752  11412    2019        Chennai    07/05/19          Chennai Super Kings
# 753  11413    2019  Visakhapatnam    08/05/19          Sunrisers Hyderabad
# 754  11414    2019  Visakhapatnam    10/05/19               Delhi Capitals
# 755  11415    2019      Hyderabad    12/05/19               Mumbai Indians
#
# ...

# %%
data.isna().any()
# Out:
# id                 False
# season             False
# city                True
# date               False
# team1              False
# team2              False
# toss_winner        False
# toss_decision      False
# result             False
# dl_applied         False
# winner              True
# win_by_runs        False
# win_by_wickets     False
# player_of_match     True
# venue              False
# umpire1             True
# umpire2             True
# umpire3             True
# dtype: bool

# %%
data.describe()
# Out:
#                  id       season  dl_applied  win_by_runs  win_by_wickets
# count    756.000000   756.000000  756.000000   756.000000      756.000000
# mean    1792.178571  2013.444444    0.025132    13.283069        3.350529
# std     3464.478148     3.366895    0.156630    23.471144        3.387963
# min        1.000000  2008.000000    0.000000     0.000000        0.000000
# 25%      189.750000  2011.000000    0.000000     0.000000        0.000000
# 50%      378.500000  2013.000000    0.000000     0.000000        4.000000
# 75%      567.250000  2016.000000    0.000000    19.000000        6.000000
# max    11415.000000  2019.000000    1.000000   146.000000       10.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 756 entries, 0 to 755
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               756 non-null    int64
#  1   season           756 non-null    int64
#  2   city             749 non-null    object
#  3   date             756 non-null    object
#  4   team1            756 non-null    object
#  5   team2            756 non-null    object
#  6   toss_winner      756 non-null    object
#  7   toss_decision    756 non-null    object
#  8   result           756 non-null    object
#  9   dl_applied       756 non-null    int64
#  10  winner           752 non-null    object
#  11  win_by_runs      756 non-null    int64
#  12  win_by_wickets   756 non-null    int64
#  13  player_of_match  752 non-null    object
#  14  venue            756 non-null    object
#  15  umpire1          754 non-null    object
#  16  umpire2          754 non-null    object
# ...

# %%
data.nunique()
# Out:
# id                 756
# season              12
# city                32
# date               546
# team1               15
# team2               15
# toss_winner         15
# toss_decision        2
# result               3
# dl_applied           2
# winner              15
# win_by_runs         89
# win_by_wickets      11
# player_of_match    226
# venue               41
# umpire1             61
# umpire2             65
# umpire3             25
# dtype: int64

# %%
data.corr()
# Out:
#                       id    season  dl_applied  win_by_runs  win_by_wickets
# id              1.000000  0.668304   -0.011658    -0.039403       -0.012239
# season          0.668304  1.000000   -0.001116    -0.037529       -0.009379
# dl_applied     -0.011658 -0.001116    1.000000    -0.016349       -0.011631
# win_by_runs    -0.039403 -0.037529   -0.016349     1.000000       -0.560420
# win_by_wickets -0.012239 -0.009379   -0.011631    -0.560420        1.000000

# %%
sns.heatmap(data.corr(),annot=True)

# %%
data['player_of_match']
# Out:
# 0      Yuvraj Singh
# 1         SPD Smith
# 2           CA Lynn
# 3        GJ Maxwell
# 4         KM Jadhav
#            ...
# 751       HH Pandya
# 752        AS Yadav
# 753         RR Pant
# 754    F du Plessis
# 755       JJ Bumrah
# Name: player_of_match, Length: 756, dtype: object

# %%
data['player_of_match'].value_counts()
# Out:
# CH Gayle          21
# AB de Villiers    20
# RG Sharma         17
# MS Dhoni          17
# DA Warner         17
#                   ..
# AP Tare            1
# MF Maharoof        1
# GD McGrath         1
# AD Mascarenhas     1
# JJ Roy             1
# Name: player_of_match, Length: 226, dtype: int64

# %%
first_batting = data[data['win_by_runs']!=0]

# %%
data['win_by_runs']
# Out:
# 0      35
# 1       0
# 2       0
# 3       0
# 4      15
#        ..
# 751     0
# 752     0
# 753     0
# 754     0
# 755     1
# Name: win_by_runs, Length: 756, dtype: int64

# %%
first_batting
# Out:
#         id  season       city        date                        team1  \
# 0        1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 4        5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# 8        9    2017       Pune  2017-04-11             Delhi Daredevils
# 13      14    2017    Kolkata  2017-04-15        Kolkata Knight Riders
# 14      15    2017      Delhi  2017-04-15             Delhi Daredevils
# ..     ...     ...        ...         ...                          ...
# 741  11337    2019      Delhi    28/04/19               Delhi Capitals
# 742  11338    2019    Kolkata    28/04/19        Kolkata Knight Riders
# 743  11339    2019  Hyderabad    29/04/19          Sunrisers Hyderabad
# 745  11341    2019    Chennai    01/05/19          Chennai Super Kings
# 755  11415    2019  Hyderabad    12/05/19               Mumbai Indians
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
data['season'].unique()
# Out:
# array([2017, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2018,
#        2019], dtype=int64)

# %%
#Team won by maximum runs
data.iloc[data['win_by_runs'].idxmax()]
# Out:
# id                               44
# season                         2017
# city                          Delhi
# date                     2017-05-06
# team1                Mumbai Indians
# team2              Delhi Daredevils
# toss_winner        Delhi Daredevils
# toss_decision                 field
# result                       normal
# dl_applied                        0
# winner               Mumbai Indians
# win_by_runs                     146
# win_by_wickets                    0
# player_of_match         LMP Simmons
# venue              Feroz Shah Kotla
# umpire1                 Nitin Menon
# umpire2                   CK Nandan
# umpire3                         NaN
# Name: 43, dtype: object

# %%
data['winner']
# Out:
# 0              Sunrisers Hyderabad
# 1           Rising Pune Supergiant
# 2            Kolkata Knight Riders
# 3                  Kings XI Punjab
# 4      Royal Challengers Bangalore
#                   ...
# 751                 Mumbai Indians
# 752                 Mumbai Indians
# 753                 Delhi Capitals
# 754            Chennai Super Kings
# 755                 Mumbai Indians
# Name: winner, Length: 756, dtype: object

# %%
#Team won by maximum wickets
data.iloc[data['win_by_wickets'].idxmax()]
# Out:
# id                                                      3
# season                                               2017
# city                                               Rajkot
# date                                           2017-04-07
# team1                                       Gujarat Lions
# team2                               Kolkata Knight Riders
# toss_winner                         Kolkata Knight Riders
# toss_decision                                       field
# result                                             normal
# dl_applied                                              0
# winner                              Kolkata Knight Riders
# win_by_runs                                             0
# win_by_wickets                                         10
# player_of_match                                   CA Lynn
# venue              Saurashtra Cricket Association Stadium
# umpire1                                       Nitin Menon
# ...

# %%
data.iloc[data['win_by_wickets'].idxmax()]['winner']
# Out:
# 'Kolkata Knight Riders'

# %%
data.iloc[data['win_by_runs'].idxmax()]['winner']
# Out:
# 'Mumbai Indians'

# %%
#Team won by minimum wickets
data.iloc[data['win_by_runs'].idxmax()]
# Out:
# id                               44
# season                         2017
# city                          Delhi
# date                     2017-05-06
# team1                Mumbai Indians
# team2              Delhi Daredevils
# toss_winner        Delhi Daredevils
# toss_decision                 field
# result                       normal
# dl_applied                        0
# winner               Mumbai Indians
# win_by_runs                     146
# win_by_wickets                    0
# player_of_match         LMP Simmons
# venue              Feroz Shah Kotla
# umpire1                 Nitin Menon
# umpire2                   CK Nandan
# umpire3                         NaN
# Name: 43, dtype: object

# %%
plt.figure(figsize=(10,9))
plt.hist(first_batting['win_by_runs'])
plt.title('Runs-Distribution',fontsize=15)
plt.xlabel('Runs')
plt.show()

# %%
sns.countplot(x='win_by_runs',data=first_batting)

# %%
#second-batting
second_batting=data[data['win_by_wickets']!=0]

# %%
second_batting
# Out:
#         id  season           city        date                   team1  \
# 1        2    2017           Pune  2017-04-06          Mumbai Indians
# 2        3    2017         Rajkot  2017-04-07           Gujarat Lions
# 3        4    2017         Indore  2017-04-08  Rising Pune Supergiant
# 5        6    2017      Hyderabad  2017-04-09           Gujarat Lions
# 6        7    2017         Mumbai  2017-04-09   Kolkata Knight Riders
# ..     ...     ...            ...         ...                     ...
# 750  11346    2019         Mohali    05/05/19     Chennai Super Kings
# 751  11347    2019         Mumbai    05/05/19   Kolkata Knight Riders
# 752  11412    2019        Chennai    07/05/19     Chennai Super Kings
# 753  11413    2019  Visakhapatnam    08/05/19     Sunrisers Hyderabad
# 754  11414    2019  Visakhapatnam    10/05/19          Delhi Capitals
#
#                       team2             toss_winner toss_decision  result  \
# ...

# %%
plt.figure(figsize=(10,8))
plt.hist(second_batting['win_by_wickets'],bins=30)
plt.title('Win by wickets',fontsize=40)
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.countplot(x='season',data=data)
plt.title('SEASON',fontsize=30)
plt.show()

# %%
#selecting top 10 players 
top_players = data.player_of_match.value_counts()[:10]
top_players
# Out:
# CH Gayle          21
# AB de Villiers    20
# RG Sharma         17
# MS Dhoni          17
# DA Warner         17
# YK Pathan         16
# SR Watson         15
# SK Raina          14
# G Gambhir         13
# MEK Hussey        12
# Name: player_of_match, dtype: int64

# %%
top_players.index
# Out:
# Index(['CH Gayle', 'AB de Villiers', 'RG Sharma', 'MS Dhoni', 'DA Warner',
#        'YK Pathan', 'SR Watson', 'SK Raina', 'G Gambhir', 'MEK Hussey'],
#       dtype='object')

# %%
plt.figure(figsize=(10,9))
fig,ax=plt.subplots()
ax.set_ylim([0,20])
ax.set_ylabel('Count')
ax.set_title('Top Player of the Match Winners')
plt.title('Top Player of the Match Winners',fontsize=30)
top_players.plot.bar()
sns.barplot(x=top_players.index,y=top_players,orient='v',palette='tab10');
plt.show()

# %% [markdown]
# # From the above data analysis and visualization,It is clear that CH Gayle,AB de Villiers are the top most players of IPL.We can clearly come to know that out of every 10 players there are atleast 4 overseas players.
